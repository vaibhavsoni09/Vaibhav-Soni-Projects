# %%
import pandas as pd
import numpy as np

# %%
titanic=pd.read_csv("C:/Users/GOLU VERMA/Desktop/sachin's ppts/titanic.csv")
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.shape
# Out:
# (1309, 12)

# %%
t1=titanic.drop(['PassengerId','Name','SibSp','Parch','Ticket','Cabin','Embarked'],axis=1)

# %%
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ### Babu=labelEncoder()

# %% [markdown]
# ### t1['Name_N']=Babu.fit_transform(t1['Name'])

# %%
t1['sex']=LabelEncoder().fit_transform(t1['Sex'])
t1.head()
# Out:
#    Survived  Pclass     Sex   Age     Fare  sex
# 0         0       3    male  22.0   7.2500    1
# 1         1       1  female  38.0  71.2833    0
# 2         1       3  female  26.0   7.9250    0
# 3         1       1  female  35.0  53.1000    0
# 4         0       3    male  35.0   8.0500    1

# %%
t1.drop(['Sex'],inplace=True,axis=1)
t1.head()
# Out:
#    Survived  Pclass   Age     Fare  sex
# 0         0       3  22.0   7.2500    1
# 1         1       1  38.0  71.2833    0
# 2         1       3  26.0   7.9250    0
# 3         1       1  35.0  53.1000    0
# 4         0       3  35.0   8.0500    1

# %%
from sklearn import tree
from sklearn.model_selection import train_test_split

# %%
model=tree.DecisionTreeClassifier()

# %%
x=t2.drop(['Survived'],axis=1)
y=t2['Survived']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.25,random_state=42)

# %% [markdown]
# model.fit(x_train,y_train)

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15,10))
sns.heatmap(t1.isnull(),cmap='viridis')

# %%
t2=t1.dropna(axis=0,how='any')

# %%
t1.fillna()

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8549618320610687

# %%
# %matplotlib inline

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier(n_estimators=45)
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=45,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
model.score(x_test,y_test)
# Out:
# 0.8549618320610687

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,y_pred)
# Out:
# array([[141,  21],
#        [ 17,  83]], dtype=int64)

# %%
sns.heatmap(confusion_matrix(y_test,y_pred))

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.25,random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier 
model=RandomForestClassifier(n_estimators=40,criterion='entropy')
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=40,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[141,  21],
#        [ 17,  83]], dtype=int64)

# %%
model.score(x_test,y_test)
# Out:
# 0.8473282442748091

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.25,random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier(criterion='entropy')
dt.fit(x_train,y_train)
y_pred=dt.predict(x_test)
score=accuracy_score(y_test,y_pred)
score
# Out:
# 0.8244274809160306

# %%
from sklearn import tree
cols=list(t2.columns.values)

plt.figure(figsize=(25,25))

tree.plot_tree(dt.fit(x,y),feature_names=cols, filled=True, precision=3,proportion=True \
              ,rounded=True)
plt.show()
